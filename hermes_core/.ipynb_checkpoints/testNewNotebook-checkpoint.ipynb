# %%
import numpy as np
from hermes_core import Workspace

# %%
# 1. Create dummy data
dummy_matrix = np.ones((50, 50, 50), dtype=np.uint16)

# 2. Instantiate your Workspace
ws = Workspace(matrix=dummy_matrix, voxel_size=1.0, name="TestBlock")

# %%
# 3. Process it
ws.pad()
ws.generate_mesh()
mesh = ws.get_trimesh()

print(f"Successfully created a mesh for {ws.name}!")
print(f"Surface Area: {mesh.area}")
# Out:
# Generated mesh with 29996 faces!
# Successfully created a mesh for TestBlock!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 7
#       3 ws.generate_mesh()
#       4 mesh = ws.get_trimesh()
#       5
#       6 print(f"Successfully created a mesh for {ws.name}!")
# ----> 7 print(f"Surface Area: {mesh.area}")
#
# File ~/Projects/HERMES/Git/hermes/hermes_core/.venv/lib64/python3.11/site-packages/trimesh/caching.py:139, in cache_decorator.<locals>.get_cached(*args, **kwargs)
#     137     return self._cache.cache[name]
#     138 # value not in cache so execute the function
# --> 139 value = function(*args, **kwargs)
#     140 # store the value
#     141 if (
#     142     self._cache.force_immutable
#     143     and hasattr(value, "flags")
#     144     and len(value.shape) > 0
#     145 ):
#
# File ~/Projects/HERMES/Git/hermes/hermes_core/.venv/lib64/python3.11/site-packages/trimesh/base.py:2812, in Trimesh.area(self)
#    2802 @cache_decorator
#    2803 def area(self) -> float64:
#    2804     """
#    2805     Summed area of all triangles in the current mesh.
#    2806
#    (...)   2810       Surface area of mesh
#    2811     """
# -> 2812     area = self.area_faces.sum()
#    2813     return area
#
# File ~/Projects/HERMES/Git/hermes/hermes_core/.venv/lib64/python3.11/site-packages/trimesh/caching.py:139, in cache_decorator.<locals>.get_cached(*args, **kwargs)
#     137     return self._cache.cache[name]
#     138 # value not in cache so execute the function
# --> 139 value = function(*args, **kwargs)
#     140 # store the value
#     141 if (
#     142     self._cache.force_immutable
#     143     and hasattr(value, "flags")
#     144     and len(value.shape) > 0
#     145 ):
#
# File ~/Projects/HERMES/Git/hermes/hermes_core/.venv/lib64/python3.11/site-packages/trimesh/base.py:2825, in Trimesh.area_faces(self)
#    2815 @cache_decorator
#    2816 def area_faces(self) -> NDArray[float64]:
#    2817     """
#    2818     The area of each face in the mesh.
#    2819
#    (...)   2823       Area of each face
#    2824     """
# -> 2825     return triangles.area(crosses=self.triangles_cross)
#
# File ~/Projects/HERMES/Git/hermes/hermes_core/.venv/lib64/python3.11/site-packages/trimesh/caching.py:139, in cache_decorator.<locals>.get_cached(*args, **kwargs)
#     137     return self._cache.cache[name]
#     138 # value not in cache so execute the function
# --> 139 value = function(*args, **kwargs)
#     140 # store the value
#     141 if (
#     142     self._cache.force_immutable
#     143     and hasattr(value, "flags")
#     144     and len(value.shape) > 0
#     145 ):
#
# File ~/Projects/HERMES/Git/hermes/hermes_core/.venv/lib64/python3.11/site-packages/trimesh/base.py:935, in Trimesh.triangles_cross(self)
#     925 @cache_decorator
#     926 def triangles_cross(self) -> NDArray[float64]:
#     927     """
#     928     The cross product of two edges of each triangle.
#     929
#    (...)    933       Cross product of each triangle
#     934     """
# --> 935     crosses = triangles.cross(self.triangles)
#     936     return crosses
#
# File ~/Projects/HERMES/Git/hermes/hermes_core/.venv/lib64/python3.11/site-packages/trimesh/caching.py:139, in cache_decorator.<locals>.get_cached(*args, **kwargs)
#     137     return self._cache.cache[name]
#     138 # value not in cache so execute the function
# --> 139 value = function(*args, **kwargs)
#     140 # store the value
#     141 if (
#     142     self._cache.force_immutable
#     143     and hasattr(value, "flags")
#     144     and len(value.shape) > 0
#     145 ):
#
# File ~/Projects/HERMES/Git/hermes/hermes_core/.venv/lib64/python3.11/site-packages/trimesh/base.py:899, in Trimesh.triangles(self)
#     888 """
#     889 Actual triangles of the mesh (points, not indexes)
#     890
#    (...)    894   Points of triangle vertices
#     895 """
#     896 # use of advanced indexing on our tracked arrays will
#     897 # trigger a change flag which means the hash will have to be
#     898 # recomputed. We can escape this check by viewing the array.
# --> 899 return self.vertices.view(np.ndarray)[self.faces]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
